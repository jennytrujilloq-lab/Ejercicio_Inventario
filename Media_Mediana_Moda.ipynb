# %% [markdown]
# <a href="https://colab.research.google.com/github/jennytrujilloq-lab/Ejercicio_Inventario/blob/main/Media_Mediana_Moda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# La pandilla de las manzanas. Imajina que un grupo de amigos quiere saber mas sobre su cosecha de manzanas. Cosecha 10 manzanas y quiere analizar su peso, para ver como es su producción de este año.
# Queremos calcular:
# - El peso promedio de las manzanas (Media)
# - El peso central (Mediana)
# - El peso mas común (Moda)
# Desviación estandar = Que tanto varian los pesos.

# %%
1 import nuppi as np
2 import statistics as stats
3
4#Pesos de las manzanas en gramos
5 manzanas = [150, 180, 200, 170, 150, 190, 200, 210, 150, 180]
6
7#Estadisticas descriptivas
8media = np.mean(manzanas) # promedio
9mediana = np.median(manzanas) #valor central
10media = np.mean(manzanas) #valor mas común
11desviacion = np.std(manzanas) #variabilidad de los pesos
12
13#Resultados
14print(f"Analisis de la cosecha de manzanas")
15print(f"Peso promedio de las manzanas: {media} gramos")
16print(f"Peso central de las manzanas: {mediana} gramos")
17print(f"Peso mas comun de las manzanas: {moda} gramos)
18print(f"Desviación estandar: {desviación} gramos")
19
# Out:
#   File "/tmp/ipykernel_3083/4030893362.py", line 8
#     8media = np.mean(manzanas) # promedio
#     ^
# SyntaxError: invalid decimal literal
